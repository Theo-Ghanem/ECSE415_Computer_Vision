# %% [markdown]
# # ECSE 415 - Assignment 4:  Neural Networks
# ## Theo Ghanem 260972584

# %% [markdown]
# ## Part 1 - CIFAR-10 Classification using Convolution Neural Network

# %%
import torch
from torch import nn
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# %% [markdown]
# Check the version of PyTorch and CUDA to make sure my laptop's GPU is detected properly

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
print("-----------------------------")
print(torch.version.cuda)
print(f'PyTorch version: {torch.__version__}')
print('*'*10)
print(f'_CUDA version: ')
print('*'*10)
print(f'Available GPU devices: {torch.cuda.device_count()}')
print(f'Device Name: {torch.cuda.get_device_name()}')
# Out:
# cuda:0
# -----------------------------
# 12.1
# PyTorch version: 2.2.1+cu121
# **********
# _CUDA version:
# **********
# Available GPU devices: 1
# Device Name: NVIDIA GeForce RTX 3050 Ti Laptop GPU

# %% [markdown]
# ### 1. Implement a shallow CNN with the layers mentioned below.
# • A Convolution layer with 32 kernels of size 3x3
# • A ReLU activation
# • A Convolution layer with 64 kernels of size 3x3
# • A ReLU activation
# • A maxpool layer with kernels size of 2x2
# • A convolution layer with 64 kernels of size 3x3
# • A ReLU activation
# • A convolution layer with 64 kernels of size 3x3
# • A ReLU activation
# • A flattening layer. (This layer resizes a 3D tensor to a feature vector).
# • A fully connected layer with an output size of 10. (Classes should be predicted
# as numerical values (like 0-9).
#
# ### 2. Use Pytorch Class torchvision.datasets.CIFAR10 to load the dataset.
# ### 3. Training, validation and test settings are shown below.
# • 50,000 images for training (training set). Divide the 10,000 test set images of CIFAR10
# into two subsets by 1:1. 5,000 images for validation (validation set), and 5,000 images for
# final testing (test set).
# • Batch size = 32.
# • SGD optimizer with an initial learning rate of 0.002.
# • Loss function: categorical cross entropy criterion.
# • Training iteration can be 90,000 or more (If you use epoch counting, epoch can be 58 or
# more). Perform a validation every 5000 iterations (3 epochs). It may take about 30
# minutes on T4 GPU. If you don't have enough computational resources, you are allowed
# to reduce the number of images by taking a subset of this dataset or reduce the training
# iterations (epochs). State the size of your subset and iterations (epochs) in the README.
# • Use the default setting for the rest of the hyperparameters.

# %%
from torch.utils.data import Subset

# Define constants
NUM_CLASSES = 10  # Number of classes in CIFAR-10
BATCH_SIZE = 32  # Batch size for training
LEARNING_RATE = 0.002  # Initial learning rate
NUM_EPOCHS = 80  # Number of epochs for training (you can adjust this)

# Define the size of the subset you want to take
# subset_size = 10000  # Adjust this value as needed

# Define data transforms
transform = transforms.Compose([
  transforms.ToTensor(),  # Convert image to tensor
  transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalize data
])

# Load the CIFAR-10 dataset
train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

# Generate a list of indices from 0 to subset_size
# indices = list(range(subset_size))

# Create the subset
# subset_train_dataset = Subset(train_dataset, indices)

# Split the test set into validation and test sets
validation_size = 5000
test_size = len(test_dataset) - validation_size

val_dataset, _ = torch.utils.data.random_split(train_dataset, [validation_size, len(train_dataset) - validation_size])
test_dataset = torch.utils.data.Subset(test_dataset, indices=range(test_size))

# Create data loaders
# train_loader = torch.utils.data.DataLoader(subset_train_dataset, batch_size=BATCH_SIZE, shuffle=True)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Define the CNN model
class CNN(nn.Module):
  def __init__(self):
    super(CNN, self).__init__()
    self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)  # Convolution layer 1
    self.relu1 = nn.ReLU()  # ReLU activation
    self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)  # Convolution layer 2
    self.relu2 = nn.ReLU()  # ReLU activation
    self.pool = nn.MaxPool2d(kernel_size=2, stride=2)  # Max pooling layer
    self.conv3 = nn.Conv2d(64, 64, kernel_size=3, padding=1)  # Convolution layer 3
    self.relu3 = nn.ReLU()  # ReLU activation
    self.conv4 = nn.Conv2d(64, 64, kernel_size=3, padding=1)  # Convolution layer 4
    self.relu4 = nn.ReLU()  # ReLU activation
    self.flatten = nn.Flatten()  # Flatten layer
    self.fc = nn.Linear(64 * 16 * 16, NUM_CLASSES)  # Fully connected layer

  def forward(self, x):
    x = self.relu1(self.conv1(x))
    x = self.relu2(self.conv2(x))
    x = self.pool(x)
    x = self.relu3(self.conv3(x))
    x = self.relu4(self.conv4(x))
    x = self.flatten(x)
    x = self.fc(x)
    return x

# %%
import time

# Initialize the model and optimizer
model = CNN()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
model.to(device)

# Define the loss function
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE)

# Training loop
train_losses, val_losses, val_accuracies = [], [], []

start_time = time.time()  # Record the start time

for epoch in range(NUM_EPOCHS):
  # Training phase
  model.train()
  total_train_loss = 0
  for data, target in train_loader:
    data, target = data.to(device), target.to(device)  # Move data to GPU
    optimizer.zero_grad()  # Reset gradients for each batch
    output = model(data)  # Forward pass
    loss = criterion(output, target)  # Calculate loss
    loss.backward()  # Backward pass
    optimizer.step()  # Update model parameters
    total_train_loss += loss.item()

  # Validation phase (after every few training iterations)
  if (epoch + 1) % 1 == 0:  # Validate every 5th epoch
    # if train_iter % 5000 == 0:
    model.eval()
    with torch.no_grad():
      val_loss = 0
      correct = 0
      for data, target in val_loader:
        data, target = data.to(device), target.to(device)  # Move data to GPU
        output = model(data)
        val_loss += criterion(output, target).item()
        predicted = torch.argmax(output, dim=1)
        correct += (predicted == target).sum().item()
      val_acc = correct / len(val_dataset)
      val_losses.append(val_loss)
      val_accuracies.append(val_acc)
      train_losses.append(total_train_loss)
      print(f'Epoch: {epoch+1}/{NUM_EPOCHS} | Train Loss: {total_train_loss:.3f} | Val Loss: {val_loss:.3f} | Val Acc: {val_acc:.3f}')

end_time = time.time()  # Record the end time

# Save the model
PATH = './cifar_net.pth'
torch.save(model.state_dict(), PATH)

kernel3x3_runtime= end_time - start_time
print(f'Total execution time: {kernel3x3_runtime} seconds --> {kernel3x3_runtime/60} minutes')
# Out:
# Epoch: 1/80 | Train Loss: 3352.085 | Val Loss: 305.626 | Val Acc: 0.314
# Epoch: 2/80 | Train Loss: 2872.098 | Val Loss: 273.738 | Val Acc: 0.388
# Epoch: 3/80 | Train Loss: 2571.006 | Val Loss: 248.875 | Val Acc: 0.438
# Epoch: 4/80 | Train Loss: 2392.512 | Val Loss: 235.213 | Val Acc: 0.469
# Epoch: 5/80 | Train Loss: 2285.401 | Val Loss: 227.245 | Val Acc: 0.484
# Epoch: 6/80 | Train Loss: 2196.477 | Val Loss: 220.911 | Val Acc: 0.500
# Epoch: 7/80 | Train Loss: 2107.691 | Val Loss: 205.214 | Val Acc: 0.532
# Epoch: 8/80 | Train Loss: 2028.202 | Val Loss: 198.268 | Val Acc: 0.548
# Epoch: 9/80 | Train Loss: 1956.812 | Val Loss: 192.361 | Val Acc: 0.559
# Epoch: 10/80 | Train Loss: 1892.230 | Val Loss: 186.881 | Val Acc: 0.574
# Epoch: 11/80 | Train Loss: 1830.987 | Val Loss: 185.143 | Val Acc: 0.580
# Epoch: 12/80 | Train Loss: 1766.566 | Val Loss: 178.480 | Val Acc: 0.594
# Epoch: 13/80 | Train Loss: 1710.465 | Val Loss: 170.527 | Val Acc: 0.610
# Epoch: 14/80 | Train Loss: 1656.100 | Val Loss: 164.510 | Val Acc: 0.628
# Epoch: 15/80 | Train Loss: 1603.045 | Val Loss: 159.165 | Val Acc: 0.646
# Epoch: 16/80 | Train Loss: 1555.471 | Val Loss: 159.623 | Val Acc: 0.641
# Epoch: 17/80 | Train Loss: 1510.554 | Val Loss: 156.066 | Val Acc: 0.654
# Epoch: 18/80 | Train Loss: 1467.968 | Val Loss: 146.297 | Val Acc: 0.674
# Epoch: 19/80 | Train Loss: 1429.699 | Val Loss: 145.615 | Val Acc: 0.682
# Epoch: 20/80 | Train Loss: 1392.855 | Val Loss: 141.214 | Val Acc: 0.688
# Epoch: 21/80 | Train Loss: 1357.506 | Val Loss: 137.771 | Val Acc: 0.697
# Epoch: 22/80 | Train Loss: 1323.526 | Val Loss: 132.220 | Val Acc: 0.711
# Epoch: 23/80 | Train Loss: 1295.707 | Val Loss: 128.682 | Val Acc: 0.722
# Epoch: 24/80 | Train Loss: 1261.596 | Val Loss: 130.908 | Val Acc: 0.706
# Epoch: 25/80 | Train Loss: 1235.773 | Val Loss: 122.419 | Val Acc: 0.732
# Epoch: 26/80 | Train Loss: 1206.496 | Val Loss: 119.521 | Val Acc: 0.739
# Epoch: 27/80 | Train Loss: 1177.817 | Val Loss: 113.492 | Val Acc: 0.755
# Epoch: 28/80 | Train Loss: 1152.283 | Val Loss: 114.780 | Val Acc: 0.744
# Epoch: 29/80 | Train Loss: 1124.586 | Val Loss: 108.628 | Val Acc: 0.766
# Epoch: 30/80 | Train Loss: 1100.355 | Val Loss: 108.992 | Val Acc: 0.764
# Epoch: 31/80 | Train Loss: 1072.046 | Val Loss: 117.049 | Val Acc: 0.735
# Epoch: 32/80 | Train Loss: 1049.102 | Val Loss: 104.747 | Val Acc: 0.767
# Epoch: 33/80 | Train Loss: 1026.080 | Val Loss: 98.356 | Val Acc: 0.789
# Epoch: 34/80 | Train Loss: 1003.243 | Val Loss: 98.780 | Val Acc: 0.783
# Epoch: 35/80 | Train Loss: 977.673 | Val Loss: 97.695 | Val Acc: 0.788
# Epoch: 36/80 | Train Loss: 954.324 | Val Loss: 95.519 | Val Acc: 0.794
# Epoch: 37/80 | Train Loss: 930.053 | Val Loss: 93.778 | Val Acc: 0.798
# Epoch: 38/80 | Train Loss: 908.952 | Val Loss: 92.410 | Val Acc: 0.796
# Epoch: 39/80 | Train Loss: 886.727 | Val Loss: 87.136 | Val Acc: 0.812
# Epoch: 40/80 | Train Loss: 864.540 | Val Loss: 87.087 | Val Acc: 0.811
# Epoch: 41/80 | Train Loss: 841.435 | Val Loss: 83.838 | Val Acc: 0.817
# Epoch: 42/80 | Train Loss: 818.453 | Val Loss: 87.573 | Val Acc: 0.810
# Epoch: 43/80 | Train Loss: 798.175 | Val Loss: 83.168 | Val Acc: 0.817
# Epoch: 44/80 | Train Loss: 777.280 | Val Loss: 76.861 | Val Acc: 0.833
# Epoch: 45/80 | Train Loss: 754.468 | Val Loss: 74.304 | Val Acc: 0.840
# Epoch: 46/80 | Train Loss: 733.380 | Val Loss: 75.526 | Val Acc: 0.834
# Epoch: 47/80 | Train Loss: 711.314 | Val Loss: 76.702 | Val Acc: 0.833
# Epoch: 48/80 | Train Loss: 690.428 | Val Loss: 65.261 | Val Acc: 0.864
# Epoch: 49/80 | Train Loss: 668.453 | Val Loss: 59.455 | Val Acc: 0.881
# Epoch: 50/80 | Train Loss: 647.648 | Val Loss: 58.218 | Val Acc: 0.880
# Epoch: 51/80 | Train Loss: 626.615 | Val Loss: 60.680 | Val Acc: 0.870
# Epoch: 52/80 | Train Loss: 604.877 | Val Loss: 63.507 | Val Acc: 0.862
# Epoch: 53/80 | Train Loss: 584.989 | Val Loss: 57.877 | Val Acc: 0.871
# Epoch: 54/80 | Train Loss: 564.057 | Val Loss: 58.350 | Val Acc: 0.871
# Epoch: 55/80 | Train Loss: 544.187 | Val Loss: 48.296 | Val Acc: 0.901
# Epoch: 56/80 | Train Loss: 520.512 | Val Loss: 57.202 | Val Acc: 0.873
# Epoch: 57/80 | Train Loss: 500.308 | Val Loss: 43.748 | Val Acc: 0.907
# Epoch: 58/80 | Train Loss: 478.299 | Val Loss: 48.329 | Val Acc: 0.893
# Epoch: 59/80 | Train Loss: 460.156 | Val Loss: 40.660 | Val Acc: 0.915
# Epoch: 60/80 | Train Loss: 439.200 | Val Loss: 41.580 | Val Acc: 0.911
# Epoch: 61/80 | Train Loss: 415.325 | Val Loss: 35.390 | Val Acc: 0.927
# Epoch: 62/80 | Train Loss: 398.218 | Val Loss: 31.762 | Val Acc: 0.938
# Epoch: 63/80 | Train Loss: 379.029 | Val Loss: 36.647 | Val Acc: 0.919
# Epoch: 64/80 | Train Loss: 356.673 | Val Loss: 37.714 | Val Acc: 0.915
# Epoch: 65/80 | Train Loss: 336.264 | Val Loss: 31.352 | Val Acc: 0.934
# Epoch: 66/80 | Train Loss: 322.153 | Val Loss: 29.555 | Val Acc: 0.933
# Epoch: 67/80 | Train Loss: 303.517 | Val Loss: 28.389 | Val Acc: 0.939
# Epoch: 68/80 | Train Loss: 289.778 | Val Loss: 23.996 | Val Acc: 0.953
# Epoch: 69/80 | Train Loss: 272.657 | Val Loss: 38.852 | Val Acc: 0.908
# Epoch: 70/80 | Train Loss: 252.208 | Val Loss: 28.028 | Val Acc: 0.936
# Epoch: 71/80 | Train Loss: 235.234 | Val Loss: 28.237 | Val Acc: 0.938
# Epoch: 72/80 | Train Loss: 219.309 | Val Loss: 21.978 | Val Acc: 0.947
# Epoch: 73/80 | Train Loss: 205.823 | Val Loss: 14.490 | Val Acc: 0.974
# Epoch: 74/80 | Train Loss: 194.085 | Val Loss: 19.359 | Val Acc: 0.959
# Epoch: 75/80 | Train Loss: 178.427 | Val Loss: 22.590 | Val Acc: 0.946
# Epoch: 76/80 | Train Loss: 161.540 | Val Loss: 15.224 | Val Acc: 0.970
# Epoch: 77/80 | Train Loss: 150.512 | Val Loss: 16.004 | Val Acc: 0.968
# Epoch: 78/80 | Train Loss: 134.278 | Val Loss: 9.274 | Val Acc: 0.987
# Epoch: 79/80 | Train Loss: 123.438 | Val Loss: 18.757 | Val Acc: 0.962
# Epoch: 80/80 | Train Loss: 115.333 | Val Loss: 12.027 | Val Acc: 0.973
# Total execution time: 4826.490488529205 seconds --> 80.44150814215342 minutes

# %% [markdown]
# ### 4. Plot the training loss, validation loss, and validation accuracy over the training iterations (or epochs).
# #### State whether the training appears to be overfitting and why.

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))

# Plot for Training loss and Validation loss
axs[0].plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss', color='b')
axs[0].plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss', color='r')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
axs[0].set_title('Train vs Validation Loss')
axs[0].legend()
axs[0].grid(True)

# Plot for Validation accuracy
axs[1].plot(range(1, len(val_accuracies) + 1), val_accuracies*100, label='Validation Accuracy', color='g')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Accuracy (%)')
axs[1].set_title('Validation Accuracy')
axs[1].legend()
axs[1].grid(True)

# Show the plots
plt.show()

# %% [markdown]
# ### 5. Give the test accuracy on the test set from the epoch where the validation accuracy is maximum as our test accuracy result.

# %%
model.load_state_dict(torch.load(PATH))

with torch.no_grad():
  correct = 0
  total = 0
  for images, labels in test_loader:
    images = images.to(device)
    labels = labels.to(device)
    outputs = model(images)
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum().item()

print('Test Accuracy of the model on the test images: {} %'.format((correct / total) * 100))
# Out:
# Test Accuracy of the model on the test images: 70.46 %

# %% [markdown]
# ### 6. Let’s discuss the effects of the Kernel size. By changing all kernel sizes to 5x5 and training a new network with the same other hyperparameters. We can compare the run time and the test accuracy of models under different kernel sizes and briefly discuss the possible factors that affect the performance of a CNN.
#
# We can notice that the runtime of the model with a 3x3 kernel size is 80 minutes and 20 seconds, while the runtime of the model with a 5x5 kernel size is 70 minutes and 30 seconds. This is a 1 minute difference, which is not significant. The test accuracy of the model with a 3x3 kernel size is 70.5%, while the test accuracy of the model with a 5x5 kernel size is 71.5%. This is a 1% difference, which is also not significant. The model with a 5x5 kernel size performs slightly better than the model with a 3x3 kernel size in terms of accuracy which can be explained by the fact that the model has more parameters as a result and can better fit the data.
#
# Some of the possible factors that can affect the performance of a CNN are:
# - The number of layers in the network
# - The number of neurons in each layer
# - The learning rate
# - The number of epochs
# - The batch size
# - The kernel size
# - The activation function
# And much more.

# %%
class CNN(nn.Module):
  def __init__(self):
    super(CNN, self).__init__()
    self.conv1 = nn.Conv2d(3, 32, kernel_size=5, padding=2)  # Convolution layer 1
    self.relu1 = nn.ReLU()  # ReLU activation
    self.conv2 = nn.Conv2d(32, 64, kernel_size=5, padding=2)  # Convolution layer 2
    self.relu2 = nn.ReLU()  # ReLU activation
    self.pool = nn.MaxPool2d(kernel_size=2, stride=2)  # Max pooling layer
    self.conv3 = nn.Conv2d(64, 64, kernel_size=5, padding=2)  # Convolution layer 3
    self.relu3 = nn.ReLU()  # ReLU activation
    self.conv4 = nn.Conv2d(64, 64, kernel_size=5, padding=2)  # Convolution layer 4
    self.relu4 = nn.ReLU()  # ReLU activation
    self.flatten = nn.Flatten()  # Flatten layer
    self.fc = nn.Linear(64 * 16 * 16, NUM_CLASSES)  # Fully connected layer

  def forward(self, x):
    x = self.relu1(self.conv1(x))
    x = self.relu2(self.conv2(x))
    x = self.pool(x)
    x = self.relu3(self.conv3(x))
    x = self.relu4(self.conv4(x))
    x = self.flatten(x)
    x = self.fc(x)
    return x

# %%
import time

# Initialize the model and optimizer
model = CNN()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")
model.to(device)

# Define the loss function
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE)

# Training loop
train_losses, val_losses, val_accuracies = [], [], []

start_time = time.time()  # Record the start time

for epoch in range(NUM_EPOCHS):
  # Training phase
  model.train()
  total_train_loss = 0
  for data, target in train_loader:
    data, target = data.to(device), target.to(device)  # Move data to GPU
    optimizer.zero_grad()  # Reset gradients for each batch
    output = model(data)  # Forward pass
    loss = criterion(output, target)  # Calculate loss
    loss.backward()  # Backward pass
    optimizer.step()  # Update model parameters
    total_train_loss += loss.item()

  # Validation phase (after every few training iterations)
  if (epoch + 1) % 1 == 0:  # Validate every 5th epoch
    model.eval()
    with torch.no_grad():
      val_loss = 0
      correct = 0
      for data, target in val_loader:
        data, target = data.to(device), target.to(device)  # Move data to GPU
        output = model(data)
        val_loss += criterion(output, target).item()
        predicted = torch.argmax(output, dim=1)
        correct += (predicted == target).sum().item()
      val_acc = correct / len(val_dataset)
      val_losses.append(val_loss)
      val_accuracies.append(val_acc)
      train_losses.append(total_train_loss)
      print(f'Epoch: {epoch+1}/{NUM_EPOCHS} | Train Loss: {total_train_loss:.3f} | Val Loss: {val_loss:.3f} | Val Acc: {val_acc:.3f}')

end_time = time.time()  # Record the end time

# Save the model
PATH = './cifar_net.pth'
torch.save(model.state_dict(), PATH)
kernel5x5_runtime= end_time - start_time
print(f'Total execution time: {kernel5x5_runtime} seconds --> {kernel5x5_runtime/60} minutes')
# Out:
# Epoch: 1/80 | Train Loss: 3371.023 | Val Loss: 301.146 | Val Acc: 0.320
# Epoch: 2/80 | Train Loss: 2752.147 | Val Loss: 269.448 | Val Acc: 0.381
# Epoch: 3/80 | Train Loss: 2421.412 | Val Loss: 234.885 | Val Acc: 0.463
# Epoch: 4/80 | Train Loss: 2269.524 | Val Loss: 220.634 | Val Acc: 0.487
# Epoch: 5/80 | Train Loss: 2154.150 | Val Loss: 221.555 | Val Acc: 0.478
# Epoch: 6/80 | Train Loss: 2048.228 | Val Loss: 207.052 | Val Acc: 0.526
# Epoch: 7/80 | Train Loss: 1953.334 | Val Loss: 190.786 | Val Acc: 0.557
# Epoch: 8/80 | Train Loss: 1865.258 | Val Loss: 182.608 | Val Acc: 0.586
# Epoch: 9/80 | Train Loss: 1784.251 | Val Loss: 179.511 | Val Acc: 0.599
# Epoch: 10/80 | Train Loss: 1703.675 | Val Loss: 179.459 | Val Acc: 0.596
# Epoch: 11/80 | Train Loss: 1624.412 | Val Loss: 167.378 | Val Acc: 0.618
# Epoch: 12/80 | Train Loss: 1552.933 | Val Loss: 160.566 | Val Acc: 0.641
# Epoch: 13/80 | Train Loss: 1488.657 | Val Loss: 146.386 | Val Acc: 0.668
# Epoch: 14/80 | Train Loss: 1429.658 | Val Loss: 139.019 | Val Acc: 0.692
# Epoch: 15/80 | Train Loss: 1375.965 | Val Loss: 137.643 | Val Acc: 0.703
# Epoch: 16/80 | Train Loss: 1325.330 | Val Loss: 136.586 | Val Acc: 0.696
# Epoch: 17/80 | Train Loss: 1282.626 | Val Loss: 129.062 | Val Acc: 0.710
# Epoch: 18/80 | Train Loss: 1238.404 | Val Loss: 128.243 | Val Acc: 0.715
# Epoch: 19/80 | Train Loss: 1196.379 | Val Loss: 117.263 | Val Acc: 0.738
# Epoch: 20/80 | Train Loss: 1157.040 | Val Loss: 118.226 | Val Acc: 0.737
# Epoch: 21/80 | Train Loss: 1122.929 | Val Loss: 110.144 | Val Acc: 0.762
# Epoch: 22/80 | Train Loss: 1088.672 | Val Loss: 108.253 | Val Acc: 0.760
# Epoch: 23/80 | Train Loss: 1052.536 | Val Loss: 127.471 | Val Acc: 0.714
# Epoch: 24/80 | Train Loss: 1019.352 | Val Loss: 98.460 | Val Acc: 0.785
# Epoch: 25/80 | Train Loss: 988.207 | Val Loss: 100.258 | Val Acc: 0.778
# Epoch: 26/80 | Train Loss: 957.959 | Val Loss: 96.711 | Val Acc: 0.785
# Epoch: 27/80 | Train Loss: 930.754 | Val Loss: 88.669 | Val Acc: 0.802
# Epoch: 28/80 | Train Loss: 900.516 | Val Loss: 87.408 | Val Acc: 0.810
# Epoch: 29/80 | Train Loss: 871.564 | Val Loss: 81.867 | Val Acc: 0.820
# Epoch: 30/80 | Train Loss: 848.941 | Val Loss: 81.998 | Val Acc: 0.823
# Epoch: 31/80 | Train Loss: 818.743 | Val Loss: 79.545 | Val Acc: 0.824
# Epoch: 32/80 | Train Loss: 795.658 | Val Loss: 75.430 | Val Acc: 0.832
# Epoch: 33/80 | Train Loss: 765.108 | Val Loss: 79.474 | Val Acc: 0.822
# Epoch: 34/80 | Train Loss: 739.508 | Val Loss: 69.815 | Val Acc: 0.850
# Epoch: 35/80 | Train Loss: 716.201 | Val Loss: 69.659 | Val Acc: 0.839
# Epoch: 36/80 | Train Loss: 694.752 | Val Loss: 64.670 | Val Acc: 0.861
# Epoch: 37/80 | Train Loss: 668.029 | Val Loss: 62.534 | Val Acc: 0.864
# Epoch: 38/80 | Train Loss: 640.390 | Val Loss: 59.860 | Val Acc: 0.870
# Epoch: 39/80 | Train Loss: 619.762 | Val Loss: 56.701 | Val Acc: 0.877
# Epoch: 40/80 | Train Loss: 592.243 | Val Loss: 58.910 | Val Acc: 0.867
# Epoch: 41/80 | Train Loss: 568.270 | Val Loss: 50.970 | Val Acc: 0.894
# Epoch: 42/80 | Train Loss: 545.216 | Val Loss: 56.401 | Val Acc: 0.872
# Epoch: 43/80 | Train Loss: 519.983 | Val Loss: 50.076 | Val Acc: 0.891
# Epoch: 44/80 | Train Loss: 497.881 | Val Loss: 41.871 | Val Acc: 0.915
# Epoch: 45/80 | Train Loss: 473.442 | Val Loss: 42.759 | Val Acc: 0.908
# Epoch: 46/80 | Train Loss: 448.576 | Val Loss: 43.694 | Val Acc: 0.902
# Epoch: 47/80 | Train Loss: 425.167 | Val Loss: 45.179 | Val Acc: 0.902
# Epoch: 48/80 | Train Loss: 404.085 | Val Loss: 36.254 | Val Acc: 0.925
# Epoch: 49/80 | Train Loss: 380.607 | Val Loss: 36.189 | Val Acc: 0.920
# Epoch: 50/80 | Train Loss: 358.822 | Val Loss: 29.518 | Val Acc: 0.940
# Epoch: 51/80 | Train Loss: 335.225 | Val Loss: 31.807 | Val Acc: 0.935
# Epoch: 52/80 | Train Loss: 316.415 | Val Loss: 32.807 | Val Acc: 0.928
# Epoch: 53/80 | Train Loss: 288.305 | Val Loss: 27.140 | Val Acc: 0.944
# Epoch: 54/80 | Train Loss: 272.433 | Val Loss: 25.027 | Val Acc: 0.953
# Epoch: 55/80 | Train Loss: 248.279 | Val Loss: 23.188 | Val Acc: 0.956
# Epoch: 56/80 | Train Loss: 232.452 | Val Loss: 24.315 | Val Acc: 0.948
# Epoch: 57/80 | Train Loss: 212.589 | Val Loss: 18.201 | Val Acc: 0.965
# Epoch: 58/80 | Train Loss: 192.734 | Val Loss: 21.346 | Val Acc: 0.952
# Epoch: 59/80 | Train Loss: 179.296 | Val Loss: 17.338 | Val Acc: 0.967
# Epoch: 60/80 | Train Loss: 160.398 | Val Loss: 14.311 | Val Acc: 0.974
# Epoch: 61/80 | Train Loss: 145.303 | Val Loss: 12.868 | Val Acc: 0.978
# Epoch: 62/80 | Train Loss: 133.024 | Val Loss: 14.559 | Val Acc: 0.969
# Epoch: 63/80 | Train Loss: 113.771 | Val Loss: 15.653 | Val Acc: 0.965
# Epoch: 64/80 | Train Loss: 102.427 | Val Loss: 11.329 | Val Acc: 0.979
# Epoch: 65/80 | Train Loss: 87.766 | Val Loss: 12.134 | Val Acc: 0.977
# Epoch: 66/80 | Train Loss: 79.997 | Val Loss: 7.815 | Val Acc: 0.988
# Epoch: 67/80 | Train Loss: 72.497 | Val Loss: 9.690 | Val Acc: 0.980
# Epoch: 68/80 | Train Loss: 59.330 | Val Loss: 5.022 | Val Acc: 0.994
# Epoch: 69/80 | Train Loss: 47.619 | Val Loss: 18.842 | Val Acc: 0.954
# Epoch: 70/80 | Train Loss: 36.565 | Val Loss: 2.710 | Val Acc: 0.998
# Epoch: 71/80 | Train Loss: 28.585 | Val Loss: 2.273 | Val Acc: 0.999
# Epoch: 72/80 | Train Loss: 22.171 | Val Loss: 2.070 | Val Acc: 0.998
# Epoch: 73/80 | Train Loss: 18.929 | Val Loss: 1.301 | Val Acc: 1.000
# Epoch: 74/80 | Train Loss: 13.592 | Val Loss: 1.073 | Val Acc: 1.000
# Epoch: 75/80 | Train Loss: 12.043 | Val Loss: 1.597 | Val Acc: 0.999
# Epoch: 76/80 | Train Loss: 10.741 | Val Loss: 0.966 | Val Acc: 1.000
# Epoch: 77/80 | Train Loss: 8.925 | Val Loss: 0.778 | Val Acc: 1.000
# Epoch: 78/80 | Train Loss: 8.034 | Val Loss: 0.654 | Val Acc: 1.000
# Epoch: 79/80 | Train Loss: 7.422 | Val Loss: 0.638 | Val Acc: 1.000
# Epoch: 80/80 | Train Loss: 6.585 | Val Loss: 0.585 | Val Acc: 1.000
# Total execution time: 4232.72789645195 seconds --> 70.54546494086584 minutes

# %% [markdown]
# ### Plot the training loss, validation loss, and validation accuracy over the training iterations (or epochs).

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))

# Plot for Training loss and Validation loss
axs[0].plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss', color='b')
axs[0].plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss', color='r')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
axs[0].set_title('Train vs Validation Loss')
axs[0].legend()
axs[0].grid(True)

# Plot for Validation accuracy
axs[1].plot(range(1, len(val_accuracies) + 1), val_accuracies*100, label='Validation Accuracy', color='g')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Accuracy (%)')
axs[1].set_title('Validation Accuracy')
axs[1].legend()
axs[1].grid(True)

# Show the plots
plt.show()

# %% [markdown]
# ### 7. Use Pytorch Class torchvision.models.resnet18 to implement a deep network ResNet18. Set the training iteration as 6000 or more (If you use epoch counting, epoch can be 5 or more) and perform a validation on the validation set every 500 iterations (1 epoch). Give the test accuracy on the test set from the iteration (or epoch) where the validation accuracy is maximum as the test accuracy result. The rest of the hyperparameters should be the same as the above shallow CNN. Note that:
# #### 7.1 By setting the parameter pretrained, you can choose to either train a new ResNet18 model from scratch or fine-tune the ResNet18 model that has been fully trained on the ImageNet dataset.
# #### 7.2 Since the image size of CIFAR10 is 32x32 and the standard ResNet18 accepts 224x224 input by default, we may need to first resize the input image to 224x224 (You are free to use other available transformation, such as padding). Besides, the output channel of the final fully connected layer of ResNet18 needs to be modified to 10 to meet the classification requirements of CIFAR10.
# Compare the impact of using a pre-trained ResNet18 versus not and discuss the reason. Compare the test accuracy of the deep ResNet18 versus the shallow CNN.

# %%
import torch
from torch import nn
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision import models  # Import the models submodule

# Define constants
NUM_CLASSES = 10  # Number of classes in CIFAR-10
BATCH_SIZE = 32  # Batch size for training
LEARNING_RATE = 0.002  # Initial learning rate
NUM_EPOCHS = 20  # Adjust as needed (5 or more)
NUM_ITERATIONS = NUM_EPOCHS * len(train_loader)  # Total training iterations

# Data transforms (including resize)
transform = transforms.Compose([
  transforms.Resize((224, 224)),  # Resize image to 224x224
  transforms.ToTensor(),
  transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Load the dataset with the new transform
train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)

# Load validation and test sets with the same transform
val_dataset = datasets.CIFAR10(root='./data', train=False, transform=transform, download=True)
test_dataset = datasets.CIFAR10(root='./data', train=False, transform=transform, download=True)

# Create data loaders
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# Function to train and validate the model
def train_validate(model, train_loader, val_loader, optimizer, criterion):
  best_val_acc = 0
  best_model_wts = None

  for epoch in range(NUM_EPOCHS):
    for i, (data, target) in enumerate(train_loader):
      # Move data and target to device
      data, target = data.to(device), target.to(device)

      # Training phase (same as previous code)
      optimizer.zero_grad()
      output = model(data)
      loss = criterion(output, target)
      loss.backward()
      optimizer.step()

      if (i + 1) % (len(train_loader)) == 0:  # Validation every epoch
        val_loss, val_acc = validate(model, val_loader, criterion)
        print(f'Epoch: [{epoch+1}/{NUM_EPOCHS}], Step: [{i+1}/{NUM_ITERATIONS}], Val Loss: {val_loss:.3f}, Val Acc: {val_acc:.3f}')

        # Update best model based on validation accuracy
        if val_acc > best_val_acc:
          best_val_acc = val_acc
          best_model_wts = model.state_dict().copy()  # Save the state_dict of the model when validation accuracy is the best
  # At the end of training, load the best model weights
  model.load_state_dict(best_model_wts)

# Function to perform validation (same as previous code)
def validate(model, data_loader, criterion):
  model.eval()
  with torch.no_grad():
    total_val_loss = 0
    correct = 0
    for data, target in data_loader:
      data, target = data.to(device), target.to(device)  # Move data and target to device
      output = model(data)
      loss = criterion(output, target)
      total_val_loss += loss.item()
      predicted = torch.argmax(output, dim=1)
      correct += (predicted == target).sum().item()
    val_acc = correct / len(data_loader.dataset)
    return total_val_loss / len(data_loader.dataset), val_acc

# Define and load the ResNet18 model
model = models.resnet18(pretrained=False)  # Train from scratch (adjust for fine-tuning)

# Modify the last layer for 10 class output
num_ftrs = model.fc.in_features  # Number of features from the last layer
model.fc = nn.Linear(num_ftrs, NUM_CLASSES)  # Replace with 10 output neurons

# Move model to device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Optimizer and loss function (same as previous code)
optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE)
criterion = nn.CrossEntropyLoss()

# Train and validate the model
train_validate(model, train_loader, val_loader, optimizer, criterion)

# Save the model
PATH = './resnet18_cifar10.pth'
torch.save(model.state_dict(), PATH)

# Test the model
model.eval()
with torch.no_grad():
  correct = 0
  total = 0
  for images, labels in test_loader:
    images, labels = images.to(device), labels.to(device)
    outputs = model(images)
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum().item()
    
print('Test Accuracy of the model on the test images: {} %'.format((correct / total) * 100))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: [1/20], Step: [1563/31260], Val Loss: 0.051, Val Acc: 0.394
# Epoch: [2/20], Step: [1563/31260], Val Loss: 0.048, Val Acc: 0.433
# Epoch: [3/20], Step: [1563/31260], Val Loss: 0.043, Val Acc: 0.497
# Epoch: [4/20], Step: [1563/31260], Val Loss: 0.040, Val Acc: 0.528
# Epoch: [5/20], Step: [1563/31260], Val Loss: 0.038, Val Acc: 0.559
# Epoch: [6/20], Step: [1563/31260], Val Loss: 0.039, Val Acc: 0.550
# Epoch: [7/20], Step: [1563/31260], Val Loss: 0.041, Val Acc: 0.528
# Epoch: [8/20], Step: [1563/31260], Val Loss: 0.030, Val Acc: 0.656
# Epoch: [9/20], Step: [1563/31260], Val Loss: 0.032, Val Acc: 0.636
# Epoch: [10/20], Step: [1563/31260], Val Loss: 0.029, Val Acc: 0.677
# Epoch: [11/20], Step: [1563/31260], Val Loss: 0.029, Val Acc: 0.679
# Epoch: [12/20], Step: [1563/31260], Val Loss: 0.036, Val Acc: 0.605
# Epoch: [13/20], Step: [1563/31260], Val Loss: 0.035, Val Acc: 0.620
# Epoch: [14/20], Step: [1563/31260], Val Loss: 0.030, Val Acc: 0.674
# Epoch: [15/20], Step: [1563/31260], Val Loss: 0.032, Val Acc: 0.659
# Epoch: [16/20], Step: [1563/31260], Val Loss: 0.028, Val Acc: 0.687
# Epoch: [17/20], Step: [1563/31260], Val Loss: 0.023, Val Acc: 0.740
# Epoch: [18/20], Step: [1563/31260], Val Loss: 0.027, Val Acc: 0.697
# Epoch: [19/20], Step: [1563/31260], Val Loss: 0.028, Val Acc: 0.686
# Epoch: [20/20], Step: [1563/31260], Val Loss: 0.026, Val Acc: 0.718
# Test Accuracy of the model on the test images: 71.8 %

# %%
# Plotting
fig, axs = plt.subplots(1, 2, figsize=(20, 6))

# Plot for Training loss and Validation loss
# axs[0].plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss', color='b')
axs[0].plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss', color='r')
axs[0].set_xlabel('Epoch')
axs[0].set_ylabel('Loss')
axs[0].set_title('Train vs Validation Loss')
axs[0].legend()
axs[0].grid(True)

# Plot for Validation accuracy
axs[1].plot(range(1, len(val_accuracies) + 1), val_accuracies, label='Validation Accuracy', color='g')
axs[1].set_xlabel('Epoch')
axs[1].set_ylabel('Accuracy')
axs[1].set_title('Validation Accuracy')
axs[1].legend()
axs[1].grid(True)

# Show the plots
plt.show()
